# %% [markdown]
# # Real-Time Time Series Analysis Demo
#
# This notebook demonstrates the key features of the time series analysis package.
#
# ## Features Demonstrated:
# 1. Synthetic data generation
# 2. Data preprocessing
# 3. Forecasting with ARIMA and Prophet
# 4. Anomaly detection
# 5. Real-time analysis
# 6. Visualization

# %%
# Import required libraries
import sys
import os
sys.path.append('../src')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots

from data_utils import SyntheticDataGenerator, TimeSeriesConfig, DataPreprocessor
from models import ARIMAForecaster, ProphetForecaster, AnomalyDetector, ModelConfig
from visualization import TimeSeriesVisualizer, InteractiveVisualizer
from config import ConfigManager

# Set random seed for reproducibility
np.random.seed(42)

print("Libraries imported successfully!")
